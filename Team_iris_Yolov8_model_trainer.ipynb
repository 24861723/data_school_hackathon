# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/My Drive/ds_hackathon/data/code'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8m.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=100)  # train the model

output_dir = '/content/gdrive/My Drive/ds_hackathon/data/code/outputs'

# Run detection
results = model.predict(source=source_dir, save=True, save_dir=output_dir)
# Out:
# Ultralytics YOLOv8.2.78 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Move data out of colab
import shutil

# Source directory
source_dir = '/content/runs'

# Destination directory
destination_dir = '/content/gdrive/My Drive/ds_hackathon/data/results4'

# Copy the entire directory tree to the destination
shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
# Out:
# '/content/gdrive/My Drive/ds_hackathon/data/results4'

# %%
from ultralytics import YOLO

# Load model
model = YOLO('/content/yolov8n.pt')

# Specify source and output directory
source_dir = '/content/gdrive/My Drive/ds_hackathon/data/code/images/test'
output_dir = '/content/gdrive/My Drive/ds_hackathon/data/code/test/outputs'

# Run detection
results = model.predict(source=source_dir, save=True, save_dir=output_dir)

# The output annotations and images will be saved in the specified output directory
# Out:
# image 1/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p103.jpg: 480x640 (no detections), 87.4ms
# image 2/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p104.jpg: 480x640 1 knife, 7.4ms
# image 3/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p1040.jpg: 640x640 (no detections), 8.8ms
# image 4/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p105.jpg: 480x640 (no detections), 10.8ms
# image 5/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p108.jpg: 448x640 (no detections), 78.1ms
# image 6/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p1086.jpg: 640x640 (no detections), 8.7ms
# image 7/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p1115.jpg: 640x640 1 baseball bat, 8.8ms
# image 8/30 /content/gdrive/My Drive/ds_hackathon/data/code/images/test/p1134.jpg: 640x640 (no detections), 8.0ms
# ...

# %%
# Move data out of colab
import shutil

# Source directory
source_dir = '/content/runs'

# Destination directory
destination_dir = '/content/gdrive/My Drive/ds_hackathon/data/results5'

# Copy the entire directory tree to the destination
shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
# Out:
# '/content/gdrive/My Drive/ds_hackathon/data/results5'
